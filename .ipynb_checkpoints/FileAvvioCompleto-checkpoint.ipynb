# %%
#BUIL Image

# %%
# !aws ecr get-login-password --region us-east-1 | docker login --username AWS --password-stdin 715867985850.dkr.ecr.us-east-1.amazonaws.com
# Out:
# WARNING! Your password will be stored unencrypted in /home/ec2-user/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# Login Succeeded

# %%
# !docker build -t 715867985850.dkr.ecr.us-east-1.amazonaws.com/tensorflow-inference:2.12.1-cpu -f Dockerfile.inference .
# Out:
# [+] Building 0.0s (0/1)                                          docker:default
# [+] Building 0.2s (5/8)                                          docker:default
#  => [internal] load build definition from Dockerfile.inference             0.0s
#  => => transferring dockerfile: 328B                                       0.0s
#  => [internal] load metadata for 763104351884.dkr.ecr.us-east-1.amazonaws  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/4] FROM 763104351884.dkr.ecr.us-east-1.amazonaws.com/tensorflow-in  0.1s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 79B                                           0.0s
# [+] Building 0.4s (6/8)                                          docker:default
#  => [internal] load build definition from Dockerfile.inference             0.0s
# ...

# %%
# !docker build -t 715867985850.dkr.ecr.us-east-1.amazonaws.com/tensorflow-training:2.12.0-cpu-py310 -f Dockerfile.train .

# %%
# !docker images

# %%
# %%sh
# # Specify an image name
# image_name=tensorflow-inference
# echo "image_name: ${image_name} ######################"
#
# account=$(aws sts get-caller-identity --query Account --output text)
# echo "account: ${account} ######################"
#
# # Get the region defined in the current configuration (default to us-west-2 if none defined)
# region=$(aws configure get region)
# echo "region: ${region} ######################"
#
# fullname="${account}.dkr.ecr.${region}.amazonaws.com/${image_name}:2.12.1-cpu"
# echo "fullname: ${fullname} ######################"
# aws ecr create-repository --repository-name "${image_name}"
# Out:
# image_name: tensorflow-inference ######################
# account: 715867985850 ######################
# region: us-east-1 ######################
# fullname: 715867985850.dkr.ecr.us-east-1.amazonaws.com/tensorflow-inference:2.12.1-cpu ######################
# An error occurred (RepositoryAlreadyExistsException) when calling the CreateRepository operation: The repository with name 'tensorflow-inference' already exists in the registry with id '715867985850'
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[19], line 1
# ...

# %%
# %%sh
# # Specify an image name
# image_name=tensorflow-training
# echo "image_name: ${image_name} ######################"
#
# account=$(aws sts get-caller-identity --query Account --output text)
# echo "account: ${account} ######################"
#
# # Get the region defined in the current configuration (default to us-west-2 if none defined)
# region=$(aws configure get region)
# echo "region: ${region} ######################"
#
# fullname="${account}.dkr.ecr.${region}.amazonaws.com/${image_name}:2.12.0-cpu-py310"
# echo "fullname: ${fullname} ######################"
# aws ecr create-repository --repository-name "${image_name}"

# %%
# !docker images
# Out:
# REPOSITORY                                                          TAG                IMAGE ID       CREATED             SIZE
# 715867985850.dkr.ecr.us-east-1.amazonaws.com/tensorflow-inference   2.12.1-cpu         394f0ce736b8   20 seconds ago      4.79GB
# 763104351884.dkr.ecr.us-east-1.amazonaws.com/tensorflow-inference   2.12.1-cpu         9f00952d6036   4 minutes ago       4.79GB
# <none>                                                              <none>             f51d551d2466   54 minutes ago      4.79GB
# <none>                                                              <none>             c744c7ca275e   54 minutes ago      4.79GB
# <none>                                                              <none>             8eede9ab77ae   58 minutes ago      4.79GB
# <none>                                                              <none>             61209748e60e   About an hour ago   4.79GB
# ...

# %%
# !docker push 715867985850.dkr.ecr.us-east-1.amazonaws.com/tensorflow-training:2.12.0-cpu-py310

# %%
# !docker push 715867985850.dkr.ecr.us-east-1.amazonaws.com/tensorflow-inference:2.12.1-cpu
# Out:
# The push refers to repository [715867985850.dkr.ecr.us-east-1.amazonaws.com/tensorflow-inference]
#
# 4f6d7e9e: Preparing
# 595a13b3: Preparing
# 6509fa23: Preparing
# 317a369c: Preparing
# aa6bf867: Preparing
# 5fe54574: Preparing
# d2bf9b69: Preparing
# 8bd87bc0: Preparing
# 3aa5a3e6: Preparing
# 7b1f5c1a: Preparing
# 927467f3: Preparing
# a10f9d9e: Preparing
# b2a790b0: Preparing
# 0a1ddd25: Preparing
# 0da2bc58: Preparing
# 8d0b82fe: Preparing
# f8627ca7: Preparing
# a64e0fa4: Preparing
# dd676f20: Preparing
# fe54574: Waiting g
# 2bf9b69: Waiting g
# bd87bc0: Waiting g
# aa5a3e6: Waiting g
# 79945bca: Preparing
# c5dbed38: Preparing
# 80a9125d: Preparing
# 64e94a15: Preparing
# 37bf1d61: Preparing
# 8df97c44: Preparing
# 764747b4: Preparing
# 1a68f579: Preparing
# b1f5c1a: Waiting g
# 64e0fa4: Waiting g
# d676f20: Waiting g
# d0b82fe: Waiting g
# 8627ca7: Waiting g
# 54313ca: Waiting g
# 06bc507: Waiting g
# 0903db8c: Preparing
# a68f579: Waiting g
# eef5eea: Waiting g
# ...

# %%
from sagemaker import get_execution_role
from sagemaker.estimator import Estimator
import os

role=get_execution_role()

hyperparameters={'epochs': 1}

estimator=Estimator(
    image_uri='715867985850.dkr.ecr.us-east-1.amazonaws.com/tensorflow-training:2.12.0-cpu-py310',
    role=role,
    instance_count=1,
    instance_type='ml.p2.xlarge',
    hyperparameters=hyperparameters,
    output_path='s3://itfilippoconsole/data/output'
)

print('##### ESTIMATOR FIT STARTED')
estimator.fit('s3://itfilippoconsole/data/input/house_price_regression_dataset.csv')
print('##### ESTIMATOR FIT COMPLETED')

# %%
from sagemaker import get_execution_role
import boto3
import datetime
from time import gmtime, strftime

# https://docs.aws.amazon.com/sagemaker/latest/dg/realtime-endpoints-deployment.html

#Set up autenticazione
my_session = boto3.session.Session()
aws_region = my_session.region_name
sagemaker_client = boto3.client('sagemaker', region_name=aws_region)
sagemaker_role = get_execution_role()

model_name = 'il-top-vendetta'

# Create model
create_model_response = sagemaker_client.create_model(
    ModelName = model_name,
    ExecutionRoleArn = sagemaker_role,
    PrimaryContainer = {
        'Image': '715867985850.dkr.ecr.us-east-1.amazonaws.com/tensorflow-inference:2.12.1-cpu',
        'ModelDataUrl': 's3://itfilippoconsole/data/output/tensorflow-training-2024-11-22-12-53-11-429/output/model.tar.gz',
    })
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml

# %%
# Create an endpoint config name. Here we create one based on the date  
# so it we can search endpoints based on creation time.
endpoint_config_name = 'la-mia-prima-api-inferenza-config'

instance_type = 'ml.m5.large'

endpoint_config_response = sagemaker_client.create_endpoint_config(
    EndpointConfigName=endpoint_config_name,
    # You will specify this name in a CreateEndpoint request.
    # List of ProductionVariant objects, one for each model that you want to host at this endpoint.
    ProductionVariants=[
        {
            "VariantName": "variant1", # The name of the production variant.
            "ModelName": model_name,
            "InstanceType": instance_type, # Specify the compute instance type.
            "InitialInstanceCount": 1 # Number of instances to launch initially.
        }
    ]
)

print(f"Created EndpointConfig: {endpoint_config_response['EndpointConfigArn']}")
# Out:
# Created EndpointConfig: arn:aws:sagemaker:us-east-1:715867985850:endpoint-config/la-mia-prima-api-inferenza-config

# %%
# The name of the endpoint. The name must be unique within an AWS Region in your AWS account.
endpoint_name = 'my-first-custom-endpoint'

create_endpoint_response = sagemaker_client.create_endpoint(
                                            EndpointName=endpoint_name, 
                                            EndpointConfigName=endpoint_config_name)
